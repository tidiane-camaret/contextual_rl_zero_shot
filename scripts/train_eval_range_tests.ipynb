# %%
import numpy as np
x = np.arange(10)
y = np.geomspace(0.002, 0.2, 10)

#plot the data
import matplotlib.pyplot as plt
plt.plot(x, y)  
# plot y = 0.02
plt.axhline(y=0.02, color='r', linestyle='--')
plt.show()

# %%
y
# Out:
# array([0.002     , 0.0033362 , 0.00556512, 0.00928318, 0.01548527,
#        0.02583099, 0.04308869, 0.07187627, 0.11989685, 0.2       ])

# %%
# 5 middle values
y_m = y[2:8]
# average of y_m{i}, y_m{i+1}
(y_m[1:] + y_m[:-1]) / 2
# Out:
# array([0.00742415, 0.01238423, 0.02065813, 0.03445984, 0.05748248])
